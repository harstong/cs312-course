# %% [markdown]
# ![](../images/cs312.png)
# ***
#
# # 02 Prepare : Reading
#
# ## 1 - Objectives
#
# - Introduction to OpenCV.
# - Learning to use OpenCV to load, modify and save images. (ie., Learn how to use imread(), imwrite() and display images in a notebook.)

# %% [markdown]
# ## 2 - Topic
#
# Computer Vision is continuing to be an important part of computer science. Below is the "about" section from opencv.org. We will be using the Python interface for this course.  **Note:** Many of the OpenCV python examples assume that you are running your python code in a "normal" system and not in a Jupyter Notebook.  For example, display images in a notebook is a little different that in a normal python IDE.
#
#
# > **About**
#
# > OpenCV (Open Source Computer Vision Library) is an open source computer vision and machine learning software library. OpenCV was built to provide a common infrastructure for computer vision applications and to accelerate the use of machine perception in the commercial products. Being a BSD-licensed product, OpenCV makes it easy for businesses to utilize and modify the code.
#
# > The library has more than 2500 optimized algorithms, which includes a comprehensive set of both classic and state-of-the-art computer vision and machine learning algorithms. These algorithms can be used to detect and recognize faces, identify objects, classify human actions in videos, track camera movements, track moving objects, extract 3D models of objects, produce 3D point clouds from stereo cameras, stitch images together to produce a high resolution image of an entire scene, find similar images from an image database, remove red eyes from images taken using flash, follow eye movements, recognize scenery and establish markers to overlay it with augmented reality, etc. OpenCV has more than 47 thousand people of user community and estimated number of downloads exceeding 14 million. The library is used extensively in companies, research groups and by governmental bodies.
#
# > Along with well-established companies like Google, Yahoo, Microsoft, Intel, IBM, Sony, Honda, Toyota that employ the library, there are many startups such as Applied Minds, VideoSurf, and Zeitera, that make extensive use of OpenCV. OpenCV’s deployed uses span the range from stitching streetview images together, detecting intrusions in surveillance video in Israel, monitoring mine equipment in China, helping robots navigate and pick up objects at Willow Garage, detection of swimming pool drowning accidents in Europe, running interactive art in Spain and New York, checking runways for debris in Turkey, inspecting labels on products in factories around the world on to rapid face detection in Japan.
#
# > It has C++, C, Python, Java and MATLAB interfaces and supports Windows, Linux, Android and Mac OS. OpenCV leans mostly towards real-time vision applications and takes advantage of MMX and SSE instructions when available. A full-featured CUDA and OpenCL interfaces are being actively developed right now. There are over 500 algorithms and about 10 times as many functions that compose or support those algorithms. OpenCV is written natively in C++ and has a templated interface that works seamlessly with STL containers.

# %% [markdown]
# ## 3 - Reading
#
# **Images**
#
# Images contain small pixels where each pixel represents a color for that image.
#
# Grayscale images have each pixel represented as a number from 0 to 255.  Where 0 is black and 255 is white.
#
# ![](grayscale.gif)
#
# Color images use channels to represent different colors where each color has a byte (values 0 to 255).  The most common are RGB images (ie., Red, Green, Blue).  Note the different ordering of RGB in the following formats.
#
# ![](colorformats.gif)
#
# The number of pixels for an image can be mearsured using DPI [Dot-per-inch](https://en.wikipedia.org/wiki/Dots_per_inch) or PPI (Pixels Per Inch).
#
# ![](dpi.png)

# %% [markdown]
# **OpenCV**
# - The main website for Opencv is [www.OpenCV.org](http://www.opencv.org) and it is a great resource for examples and documentation.
# - This week, we will be focusing on the basics of load and saving images.
# - Please downlown this notebook and run and change the code examples.
# - Link to a [document on channels](https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_core/py_basic_ops/py_basic_ops.html).

# %%
# These are the libraries used in this notebook - you must run this cell
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ---
# **Display images in Jupyter Notebook**
# - The first section to understand is how to use Matplotlib to display OpenCV images.

# %%
img = cv2.imread('image1.jpg')

# In order to display using MatPlotLib, RGB channels need to be swapped
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Sample Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ---
# **imread()**
# - The function imread() is used to load an image using OpenCV.  There is a small example [here](https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_gui/py_image_display/py_image_display.html).
#
# Example of loading an image as a gray scale

# %%
import numpy as np
import cv2

img = cv2.imread('rgbg.png', 0)

# Display the image
plt.imshow(img, cmap='gray')
plt.title('Sample Image'), plt.xticks([]), plt.yticks([])
plt.show()

# Load an color image in grayscale
print(img)
# Out:
# [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
#  [255 255  76 255 255 149 255 255  29 255 255  64 128 215 255 255]
# ...

# %%
# Example of loading an image as a RGB image
import numpy as np
import cv2

# Load an color image in RGB
img = cv2.imread('rgbg.png', cv2.IMREAD_COLOR)
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [  0   0 255]
#   [255 255 255]
#   [255 255 255]
#   [  0 255   0]
#   [255 255 255]
#   [255 255 255]
#   [255   0   0]
#   [255 255 255]
#   [255 255 255]
#   [ 64  64  64]
#   [128 128 128]
#   [215 215 215]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [  0   0 255]
#   [255 255 255]
#   [255 255 255]
#   [  0 255   0]
#   [255 255 255]
# ...

# %% [markdown]
# Format of an image
#
# - Images loaded with imread() are numpy arrays.
# - Each color of an image is called a channel.  RGB images have 3 channels, a grayscale has one channel.
# - If the image has transparency, then the image will have an alpha channel.

# %%
# shape function
# To display information about an image, use the shape function
# It returns a tuple of number of rows, columns and channels
print(img.shape)

height, width, channels = img.shape
print(height, width, channels)
# Out:
# (16, 16, 3)
# 16 16 3

# %%
# size function
# To get the size of an image in bytes, use size.
print(img.size)
# Out:
# 768

# %%
# It is very important to know the data type of a numpy so you can use it correctly.
# The function is dtype.  Review numpy functions to convert 
print(img.dtype)
# Out:
# uint8

# %% [markdown]
# Splitting and merging image channels
#
# - the different colors of an image are called channels.  These channels can be split apart and merged together

# %%
# You can split the image channels using the command split.
img = cv2.imread('rgbg.png')
plt.imshow(img, cmap='gray')
plt.title('Sample Image'), plt.xticks([]), plt.yticks([])
plt.show()

b, g, r = cv2.split(img)
print(r)
# Out:
# [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
# ...

# %%
print(g)
# Out:
# [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
#  [255 255   0 255 255 255 255 255   0 255 255  64 128 215 255 255]
# ...

# %%
print(b)
# Out:
# [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
# ...

# %%
# You can merge channels using merge()
newimg = cv2.merge([b, g, r])
print(newimg)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [  0   0 255]
#   [255 255 255]
#   [255 255 255]
#   [  0 255   0]
#   [255 255 255]
#   [255 255 255]
#   [255   0   0]
#   [255 255 255]
#   [255 255 255]
#   [ 64  64  64]
#   [128 128 128]
#   [215 215 215]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [  0   0 255]
#   [255 255 255]
#   [255 255 255]
#   [  0 255   0]
#   [255 255 255]
# ...

# %%
# You can use numpy to extract the channel which is faster
b = img[:,:,0]
g = img[:,:,1]
r = img[:,:,2]
print(b)
# Out:
# [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
#  [255 255   0 255 255   0 255 255 255 255 255  64 128 215 255 255]
# ...

# %%
# Changing all reds in an image to zero
img = cv2.imread('rgbg.png', cv2.IMREAD_COLOR)
r = img[:,:,2]
print(r)

img[:,:,2] = 0

r = img[:,:,2]
print(r)
# Out:
# [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
#  [255 255 255 255 255   0 255 255   0 255 255  64 128 215 255 255]
# ...

# %%
img = cv2.imread('image1.jpg')

# Changing all reds in an image to zero
img[:,:,2] = 0

img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Sample Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ---
# **imwrite()**
# - Once you have loaded an image, you can save it with the imwrite() function
#
# ```python
# cv2.imwrite('newimage.png', img)
# ```
#
# Example of loading and saving an image.  Note that I'm reading and writing two different image formats.  OpenCV can handle many different image formats.
# ```python
# import numpy as np
# import cv2
#
# img = cv2.imread('image.jpg', 0)
# cv2.imwrite('newimage.png', img)
# ```

# %% [markdown]
# ---
# **numpy**
# - The format of the image loaded from imread() and saved to imwrite() is a numpy array.  This will allow us to modify images using numpy commands and statements.
# - Here is a short webpage on how OpenCV and numpy work [together](https://docs.opencv.org/3.1.0/d3/df2/tutorial_py_basic_ops.html).
